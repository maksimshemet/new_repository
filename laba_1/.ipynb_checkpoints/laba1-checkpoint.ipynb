# %% [markdown]
# Лаба_1
# Для кожної із адміністративних одиниць України завантажити тестові структуровані файли, що містять значення VHI-індексу. Ця процедура має бути автоматизована, параметром процедури має бути індекс (номер) області. При зберіганні файлу до його імені потрібно додати дату та час завантаження

# %%
from urllib.request import urlopen
import pandas as pd
import collections
from datetime import datetime

now = datetime.now()
oblasti = (
    "1: Cherkasy",
    "2: Chernihiv",
    "3: Chernivtsi",
    "4: Crimea",
    "5: Dnipropetrovs'k",
    "6: Donets'k",
    "7: Ivano-Frankivs'k",
    "8: Kharkiv",
    "9: Kherson",
    "10: Khmel'nyts'kyy",
    "11: Kiev",
    "12: Kiev City",
    "13: Kirovohrad",
    "14: Luhans'k",
    "15: L'viv",
    "16: Mykolayiv",
    "17: Odessa",
    "18: Poltava",
    "19: Rivne",
    "20: Sevastopol'",
    "21: Sumy",
    "22: Ternopil",
    "23: Transcarpathia",
    "24: Vinnytsya",
    "25: Volyn",
    "26: Zaporizhzhya",
    "27: Zhytomyr"
                )
for i in oblasti:
    print(i)
id = input("Введите ID области:")
url = "https://www.star.nesdis.noaa.gov/smcd/emb/vci/VH/get_provinceData.php?country=UKR&provinceID={}&year1=1981&year2=2017&type=Mean".format(id)
d ='%s-%s-%s' % (now.month, now.day, now.year)
t = '%s:%s:%s' % (now.hour, now.minute, now.second)
destination = t+"_"+d+"_"+str(oblasti[int(id)-1])+".csv"
name = destination.replace(" ","_")
print(name)
vhi_url = urlopen(url)
out = open(name, "wb")
out.write(vhi_url.read())
out.close()
print ("VHI is downloaded...")
# Out:
# 1: Cherkasy
# 2: Chernihiv
# 3: Chernivtsi
# 4: Crimea
# 5: Dnipropetrovs'k
# 6: Donets'k
# 7: Ivano-Frankivs'k
# 8: Kharkiv
# 9: Kherson
# 10: Khmel'nyts'kyy
# 11: Kiev
# 12: Kiev City
# 13: Kirovohrad
# 14: Luhans'k
# 15: L'viv
# 16: Mykolayiv
# 17: Odessa
# 18: Poltava
# 19: Rivne
# 20: Sevastopol'
# 21: Sumy
# 22: Ternopil
# 23: Transcarpathia
# 24: Vinnytsya
# 25: Volyn
# 26: Zaporizhzhya
# 27: Zhytomyr
# Введите ID области:10
# 10:24:13_3-1-2017_10:_Khmel'nyts'kyy.csv
# VHI is downloaded...

# %% [markdown]
# 1)Зчитати завантажені текстові файли у фрейм (детальніше про роботу із фреймами буде розказано у подальших лабораторних роботах). Імена стовбців фрейму мають бути змістовними та легкими для сприйняття (не повинно бути спеціалізованих символів, пробілів тощо). Ця задача має бути реалізована у вигляді окремої процедури, яка на вхід приймає шлях до директорії, в якій зберігаються файли

# %%
#вивід таблиці
df = pd.read_csv(name , index_col=False, header=1, skipfooter=1, engine='python',
                 names=['year', 'week', 'SMN', 'SMT', 'VCI', 'TCI', 'VHI'], delimiter='\,\s+|\s+|\,')
df
# Out:
# /usr/local/lib/python3.5/dist-packages/pandas/core/ops.py:792: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   result = getattr(x, name)(y)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-18-75cf88ce0240> in <module>()
#       2 df = pd.read_csv(name , index_col=False, header=1, skipfooter=1, engine='python',
#       3                  names=['year', 'week', 'SMN', 'SMT', 'VCI', 'TCI', 'VHI'], delimiter='\,\s+|\s+|\,')
# ----> 4 y = df[df.year == 'year']
#       5
#       6 y
#
# /usr/local/lib/python3.5/dist-packages/pandas/core/ops.py in wrapper(self, other, axis)
#     853
#     854             with np.errstate(all='ignore'):
# --> 855                 res = na_op(values, other)
#     856             if isscalar(res):
#     857                 raise TypeError('Could not compare %s type with Series' %
#
# /usr/local/lib/python3.5/dist-packages/pandas/core/ops.py in na_op(x, y)
#     792                     result = getattr(x, name)(y)
#     793                 if result is NotImplemented:
# --> 794                     raise TypeError("invalid type comparison")
#     795             except AttributeError:
#     796                 result = op(x, y)
#
# TypeError: invalid type comparison

# %%
#Ряд VHI для області за рік, пошук екстремумів (min та max)
year = input("Введите год: ")
df2 = df[(df['year']==int(year))]
print("Максимальный VHI: "+str(max(df2['VHI'])))
print("Минимальный VHI: "+str(min(df2['VHI'])))
# Out:
# Введите год: 2016
# Максимальный VHI: 56.82
# Минимальный VHI: 24.11

# %%
#помірна посуха
df[(df['VHI']<35)]
# Out:
#       year  week    SMN     SMT    VCI    TCI    VHI
# 22    1982     6  0.056  267.47  39.55  30.27  34.91
# 23    1982     7  0.055  268.58  35.19  31.10  33.14
# 24    1982     8  0.057  270.15  33.35  32.09  32.72
# 25    1982     9  0.057  271.60  30.82  34.71  32.77
# 26    1982    10  0.057  273.10  27.66  36.79  32.23
# 27    1982    11  0.063  275.28  26.28  34.48  30.38
# 28    1982    12  0.074  277.68  25.86  36.39  31.12
# 29    1982    13  0.085  279.65  22.76  40.53  31.65
# 30    1982    14  0.098  281.32  18.26  46.96  32.61
# 56    1982    40  0.241  287.77  37.99  31.74  34.87
# 57    1982    41  0.213  286.01  33.20  26.73  29.96
# 58    1982    42  0.190  284.41  32.70  23.62  28.16
# 59    1982    43  0.165  282.63  32.42  22.36  27.39
# 60    1982    44  0.143  280.65  32.85  17.25  25.05
# 61    1982    45  0.116  278.11  29.59  18.01  23.80
# 62    1982    46  0.094  275.77  27.12  18.52  22.82
# 63    1982    47  0.078  273.40  28.51  20.32  24.41
# 64    1982    48  0.066  270.63  29.19  25.49  27.34
# 65    1982    49  0.057  268.48  29.21  27.86  28.53
# 66    1982    50  0.050  266.59  27.74  28.01  27.87
# 67    1982    51  0.048  264.57  31.33  28.33  29.83
# 68    1982    52  0.045  263.10  32.98  31.00  31.99
# 69    1983     1  0.044  262.64  33.09  32.41  32.75
# 70    1983     2  0.045  263.56  35.38  31.03  33.21
# 71    1983     3  0.048  265.07  40.56  27.15  33.85
# 72    1983     4  0.053  266.79  45.87  23.21  34.54
# 73    1983     5  0.055  267.60  44.16  25.26  34.71
# 74    1983     6  0.053  268.00  37.29  29.22  33.26
